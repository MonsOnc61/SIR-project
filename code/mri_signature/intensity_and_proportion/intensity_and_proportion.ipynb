# %% [markdown]
# ### Intensité et porportion des lésions (01 and 07 -> 13)

# %%
import SimpleITK as sitk
import numpy as np
import csv
from pathlib import Path

data_path = Path.cwd().parent.parent.parent / "data"
mslesseg_path = data_path / "01_MSLesSeg_Dataset"
registration_path = data_path / "07_registered_aseg_results"

if not registration_path.exists():
    raise FileNotFoundError(f"You must run first the script of 'aseg_t1_registration.py' to generate the registered data")

csv_folder_path = data_path / "13_lesion_info_per_label_csv"
csv_folder_path.mkdir(parents = True, exist_ok = True)

# %%
"""
01 and 07 -> 13
Ce script prend envrion 22 minutes.
"""

# =============================
# INDEXATION DES FICHIERS
# =============================
aseg_split_path_dict = {}
t1_split_path_dict = {}

for aseg_path in registration_path.rglob("*_aseg.nii.gz"):
    parts = aseg_path.stem.split("_")
    arg = tuple(parts[:2]) if len(parts) == 3 else parts[0]
    aseg_split_path_dict[arg] = aseg_path

for t1_path in mslesseg_path.rglob("*_T1.nii.gz"):
    parts = t1_path.stem.split("_")
    arg = tuple(parts[:2]) if len(parts) == 3 else parts[0]
    t1_split_path_dict[arg] = t1_path

# =============================
# LUT FREESURFER ASEG
# =============================
exclude_labels = [0, 4, 5, 43, 44]

freesurfer_aseg_labels = {
    # Structure de base et ventricules
    0:  "Background",
    2:  "Left-Cerebral-White-Matter",
    3:  "Left-Cerebral-Cortex",
    4:  "Left-Lateral-Ventricle",
    5:  "Left-Inf-Lat-Vent",
    7:  "Left-Cerebellum-White-Matter",
    8:  "Left-Cerebellum-Cortex",
    10: "Left-Thalamus-Proper",
    11: "Left-Caudate",
    12: "Left-Putamen",
    13: "Left-Pallidum",
    14: "3rd-Ventricle",
    15: "4th-Ventricle",
    16: "Brain-Stem",
    17: "Left-Hippocampus",
    18: "Left-Amygdala",
    24: "CSF",
    26: "Left-Accumbens-area",
    28: "Left-VentralDC",
    30: "Left-vessel",
    31: "Left-choroid-plexus",
    
    # Structures hémisphère droit
    41: "Right-Cerebral-White-Matter",
    42: "Right-Cerebral-Cortex",
    43: "Right-Lateral-Ventricle",
    44: "Right-Inf-Lat-Vent",
    46: "Right-Cerebellum-White-Matter",
    47: "Right-Cerebellum-Cortex",
    49: "Right-Thalamus-Proper",
    50: "Right-Caudate",
    51: "Right-Putamen",
    52: "Right-Pallidum",
    53: "Right-Hippocampus",
    54: "Right-Amygdala",
    58: "Right-Accumbens-area",
    60: "Right-VentralDC",
    62: "Right-vessel",
    63: "Right-choroid-plexus",
    
    # Zones spécifiques souvent touchées par la SEP
    72: "5th-Ventricle",
    77: "WM-hypointensities",
    
    80: "non-WM-hypointensities",
    85: "Optic-Chiasm",
    
    # Corps Calleux (CC) - Segmentation fine
    251: "CC_Posterior",
    252: "CC_Mid_Posterior",
    253: "CC_Central",
    254: "CC_Mid_Anterior",
    255: "CC_Anterior",
}

# =============================
# BOUCLE PRINCIPALE
# =============================
for split in aseg_split_path_dict.keys():

    if split not in t1_split_path_dict:
        raise ValueError(f"Missing T1 file for key {split}")

    if isinstance(split, tuple):
        patient, timepoint = split
        csv_path = csv_folder_path / f"{patient}_{timepoint}_intensity_info.csv"
    else:
        patient = split
        timepoint = ""
        csv_path = csv_folder_path / f"{patient}_intensity_info.csv"

    aseg_path = aseg_split_path_dict[split]
    t1_path = t1_split_path_dict[split]
    t2_path = t1_path.parent / t1_path.name.replace("_T1.nii.gz", "_T2.nii.gz")
    flair_path = t1_path.parent / t1_path.name.replace("_T1.nii.gz", "_FLAIR.nii.gz")
    mask_path = t1_path.parent / t1_path.name.replace("_T1.nii.gz", "_MASK.nii.gz")

    modalities = {
        "T1": t1_path,
        "T2": t2_path,
        "FLAIR": flair_path,
    }

    # =============================
    # LECTURE IMAGES
    # =============================
    mask_img = sitk.Cast(sitk.ReadImage(str(mask_path)) > 0, sitk.sitkUInt8)
    aseg_img = sitk.ReadImage(str(aseg_path))

    mask_cc = sitk.RelabelComponent(sitk.ConnectedComponent(mask_img))

    mask_array = sitk.GetArrayFromImage(mask_cc)
    aseg_array = sitk.GetArrayFromImage(aseg_img)

    spacing = mask_img.GetSpacing()
    voxel_volume = spacing[0] * spacing[1] * spacing[2]

    num_lesions = int(mask_array.max())
    print(f"[{patient} {timepoint}] Nombre de lésions : {num_lesions}")

    # =============================
    # PROPORTIONS ANATOMIQUES
    # =============================
    lesion_zone_proportions = {}

    for lesion_id in range(1, num_lesions + 1):
        lesion_mask = mask_array == lesion_id
        total_voxels = lesion_mask.sum()

        zone_props = {}
        for zone in np.unique(aseg_array):
            if zone in exclude_labels:
                continue

            n = np.logical_and(lesion_mask, aseg_array == zone).sum()
            if n > 0:
                zone_name = freesurfer_aseg_labels.get(zone, f"Zone_{zone}")
                zone_props[f"{zone_name}_prop"] = round(n / total_voxels, 3)

        lesion_zone_proportions[lesion_id] = zone_props

    # =============================
    # CSV HEADER
    # =============================
    zone_columns = sorted({
        k for props in lesion_zone_proportions.values()
        for k in props.keys()
    })

    header = [
        "patient", "timepoint", "lesion_id", "modality",
        "lesion_volume_mm3",
        "lesion_mean", "lesion_std",
        "lesion_min", "lesion_max", "lesion_range",
        "lesion_skew", "lesion_kurt"
    ] + zone_columns

    # =============================
    # ÉCRITURE CSV
    # =============================
    with open(csv_path, "w", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=header)
        writer.writeheader()

        for modality, img_path in modalities.items():
            img = sitk.Cast(sitk.ReadImage(str(img_path)), sitk.sitkFloat64)
            img_array = sitk.GetArrayFromImage(img)

            for lesion_id in range(1, num_lesions + 1):
                lesion_mask = mask_array == lesion_id
                voxels = img_array[lesion_mask]

                mean = round(voxels.mean(), 1)
                std = round(voxels.std(), 1)
                vmin = round(voxels.min(), 1)
                vmax = round(voxels.max(), 1)

                if voxels.size >= 3 and std > 0:
                    centered = voxels - mean
                    skew = round(np.mean(centered**3) / std**3, 2)
                    kurt = round(np.mean(centered**4) / std**4 - 3, 2)
                else:
                    skew, kurt = "", ""

                row = {
                    "patient": patient,
                    "timepoint": timepoint,
                    "lesion_id": lesion_id,
                    "modality": modality,
                    "lesion_volume_mm3": round(lesion_mask.sum() * voxel_volume, 1),
                    "lesion_mean": mean,
                    "lesion_std": std,
                    "lesion_min": vmin,
                    "lesion_max": vmax,
                    "lesion_range": round(vmax - vmin, 1),
                    "lesion_skew": skew,
                    "lesion_kurt": kurt,
                }

                for col in zone_columns:
                    row[col] = lesion_zone_proportions[lesion_id].get(col, 0)

                writer.writerow(row)

    print(f"CSV généré : {csv_path}")
# Out:
# [P10 T1] Nombre de lésions : 35
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P10_T1_intensity_info.csv
# [P10 T2] Nombre de lésions : 32
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P10_T2_intensity_info.csv
# [P11 T1] Nombre de lésions : 15
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P11_T1_intensity_info.csv
# [P11 T2] Nombre de lésions : 10
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P11_T2_intensity_info.csv
# [P12 T1] Nombre de lésions : 36
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P12_T1_intensity_info.csv
# [P12 T2] Nombre de lésions : 42
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P12_T2_intensity_info.csv
# [P12 T3] Nombre de lésions : 44
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P12_T3_intensity_info.csv
# [P13 T1] Nombre de lésions : 39
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P13_T1_intensity_info.csv
# [P13 T2] Nombre de lésions : 61
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P13_T2_intensity_info.csv
# [P14 T1] Nombre de lésions : 17
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P14_T1_intensity_info.csv
# [P14 T2] Nombre de lésions : 17
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P14_T2_intensity_info.csv
# [P14 T3] Nombre de lésions : 29
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P14_T3_intensity_info.csv
# [P14 T4] Nombre de lésions : 28
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P14_T4_intensity_info.csv
# [P15 T1] Nombre de lésions : 6
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P15_T1_intensity_info.csv
# [P16 T1] Nombre de lésions : 4
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P16_T1_intensity_info.csv
# [P17 T1] Nombre de lésions : 11
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P17_T1_intensity_info.csv
# [P18 T1] Nombre de lésions : 3
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P18_T1_intensity_info.csv
# [P19 T1] Nombre de lésions : 61
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P19_T1_intensity_info.csv
# [P19 T2] Nombre de lésions : 56
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P19_T2_intensity_info.csv
# [P19 T3] Nombre de lésions : 64
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P19_T3_intensity_info.csv
# [P19 T4] Nombre de lésions : 26
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P19_T4_intensity_info.csv
# [P1 T1] Nombre de lésions : 18
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P1_T1_intensity_info.csv
# [P1 T2] Nombre de lésions : 18
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P1_T2_intensity_info.csv
# [P1 T3] Nombre de lésions : 14
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P1_T3_intensity_info.csv
# [P20 T1] Nombre de lésions : 8
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P20_T1_intensity_info.csv
# [P20 T2] Nombre de lésions : 26
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P20_T2_intensity_info.csv
# [P20 T3] Nombre de lésions : 13
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P20_T3_intensity_info.csv
# [P21 T1] Nombre de lésions : 13
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P21_T1_intensity_info.csv
# [P22 T1] Nombre de lésions : 21
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P22_T1_intensity_info.csv
# [P22 T2] Nombre de lésions : 21
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P22_T2_intensity_info.csv
# [P23 T1] Nombre de lésions : 20
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P23_T1_intensity_info.csv
# [P25 T1] Nombre de lésions : 6
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P25_T1_intensity_info.csv
# [P26 T1] Nombre de lésions : 43
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P26_T1_intensity_info.csv
# [P27 T1] Nombre de lésions : 25
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P27_T1_intensity_info.csv
# [P28 T1] Nombre de lésions : 8
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P28_T1_intensity_info.csv
# [P28 T2] Nombre de lésions : 21
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P28_T2_intensity_info.csv
# [P29 T1] Nombre de lésions : 27
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P29_T1_intensity_info.csv
# [P2 T2] Nombre de lésions : 20
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P2_T2_intensity_info.csv
# [P2 T4] Nombre de lésions : 18
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P2_T4_intensity_info.csv
# [P30 T1] Nombre de lésions : 6
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P30_T1_intensity_info.csv
# [P31 T1] Nombre de lésions : 29
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P31_T1_intensity_info.csv
# [P31 T2] Nombre de lésions : 31
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P31_T2_intensity_info.csv
# [P32 T1] Nombre de lésions : 12
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P32_T1_intensity_info.csv
# [P33 T1] Nombre de lésions : 44
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P33_T1_intensity_info.csv
# [P33 T2] Nombre de lésions : 31
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P33_T2_intensity_info.csv
# [P34 T1] Nombre de lésions : 32
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P34_T1_intensity_info.csv
# [P35 T1] Nombre de lésions : 109
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P35_T1_intensity_info.csv
# [P36 T1] Nombre de lésions : 79
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P36_T1_intensity_info.csv
# [P37 T1] Nombre de lésions : 16
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P37_T1_intensity_info.csv
# [P38 T1] Nombre de lésions : 111
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P38_T1_intensity_info.csv
# [P39 T1] Nombre de lésions : 35
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P39_T1_intensity_info.csv
# [P3 T1] Nombre de lésions : 42
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P3_T1_intensity_info.csv
# [P3 T2] Nombre de lésions : 16
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P3_T2_intensity_info.csv
# [P3 T3] Nombre de lésions : 26
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P3_T3_intensity_info.csv
# [P3 T4] Nombre de lésions : 25
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P3_T4_intensity_info.csv
# [P40 T1] Nombre de lésions : 23
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P40_T1_intensity_info.csv
# [P41 T1] Nombre de lésions : 10
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P41_T1_intensity_info.csv
# [P42 T1] Nombre de lésions : 44
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P42_T1_intensity_info.csv
# [P43 T1] Nombre de lésions : 40
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P43_T1_intensity_info.csv
# [P44 T1] Nombre de lésions : 11
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P44_T1_intensity_info.csv
# [P45 T1] Nombre de lésions : 15
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P45_T1_intensity_info.csv
# [P46 T1] Nombre de lésions : 27
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P46_T1_intensity_info.csv
# [P47 T1] Nombre de lésions : 59
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P47_T1_intensity_info.csv
# [P48 T1] Nombre de lésions : 43
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P48_T1_intensity_info.csv
# [P49 T1] Nombre de lésions : 30
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P49_T1_intensity_info.csv
# [P4 T2] Nombre de lésions : 28
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P4_T2_intensity_info.csv
# [P50 T1] Nombre de lésions : 47
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P50_T1_intensity_info.csv
# [P50 T2] Nombre de lésions : 41
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P50_T2_intensity_info.csv
# [P51 T1] Nombre de lésions : 44
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P51_T1_intensity_info.csv
# [P51 T2] Nombre de lésions : 39
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P51_T2_intensity_info.csv
# [P52 T1] Nombre de lésions : 28
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P52_T1_intensity_info.csv
# [P52 T2] Nombre de lésions : 14
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P52_T2_intensity_info.csv
# [P53 T1] Nombre de lésions : 22
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P53_T1_intensity_info.csv
# [P53 T2] Nombre de lésions : 24
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P53_T2_intensity_info.csv
# [P54 ] Nombre de lésions : 5
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P54_intensity_info.csv
# [P55 ] Nombre de lésions : 37
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P55_intensity_info.csv
# [P56 ] Nombre de lésions : 4
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P56_intensity_info.csv
# [P57 ] Nombre de lésions : 113
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P57_intensity_info.csv
# [P58 ] Nombre de lésions : 43
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P58_intensity_info.csv
# [P59 ] Nombre de lésions : 15
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P59_intensity_info.csv
# [P5 T1] Nombre de lésions : 24
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P5_T1_intensity_info.csv
# [P5 T2] Nombre de lésions : 13
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P5_T2_intensity_info.csv
# [P60 ] Nombre de lésions : 26
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P60_intensity_info.csv
# [P61 ] Nombre de lésions : 13
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P61_intensity_info.csv
# [P62 ] Nombre de lésions : 52
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P62_intensity_info.csv
# [P63 ] Nombre de lésions : 12
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P63_intensity_info.csv
# [P64 ] Nombre de lésions : 33
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P64_intensity_info.csv
# [P65 ] Nombre de lésions : 193
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P65_intensity_info.csv
# [P66 ] Nombre de lésions : 59
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P66_intensity_info.csv
# [P67 ] Nombre de lésions : 77
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P67_intensity_info.csv
# [P68 ] Nombre de lésions : 8
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P68_intensity_info.csv
# [P69 ] Nombre de lésions : 25
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P69_intensity_info.csv
# [P6 T3] Nombre de lésions : 41
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P6_T3_intensity_info.csv
# [P70 ] Nombre de lésions : 22
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P70_intensity_info.csv
# [P71 ] Nombre de lésions : 19
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P71_intensity_info.csv
# [P72 ] Nombre de lésions : 15
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P72_intensity_info.csv
# [P73 ] Nombre de lésions : 35
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P73_intensity_info.csv
# [P74 ] Nombre de lésions : 31
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P74_intensity_info.csv
# [P75 ] Nombre de lésions : 70
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P75_intensity_info.csv
# [P7 T2] Nombre de lésions : 23
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P7_T2_intensity_info.csv
# [P8 T1] Nombre de lésions : 18
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P8_T1_intensity_info.csv
# [P8 T2] Nombre de lésions : 21
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P8_T2_intensity_info.csv
# [P9 T1] Nombre de lésions : 16
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P9_T1_intensity_info.csv
# [P9 T2] Nombre de lésions : 22
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P9_T2_intensity_info.csv
# [P9 T3] Nombre de lésions : 15
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\13_lesion_info_per_label_csv\P9_T3_intensity_info.csv
