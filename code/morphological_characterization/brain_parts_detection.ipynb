# %% [markdown]
# Automatisation de la détection des différentes parties du cerveau à partir des segmentations automatiques (aseg.nii.gz)

# %%
import SimpleITK as sitk
import csv
from pathlib import Path

data_path = Path.cwd().parent.parent / "data"

registration_folder_path = data_path / "07_registered_aseg_results"
if not registration_folder_path.exists():
    raise FileNotFoundError(f"You must run first the script of 'aseg_t1_registration.py' to generate the registered data")

csv_folder_path = data_path / "09_label_csv"
csv_folder_path.mkdir(parents = True, exist_ok = True)

# %%
"""
01 et 07 -> 09
Automatisation du script, stocker les sorties dans 09_label_csv
"""

mslesseg_path = data_path / "01_MSLesSeg_Dataset"
registration_path = data_path / "07_registered_aseg_results"

if not registration_path.exists():
    raise FileNotFoundError(
        f"You must run first the script of 'aseg_t1_registration.py' to generate the registered data"
    )

aseg_split_path_dict = {}
t1_split_path_dict = {}

for aseg_path in registration_path.rglob("*_aseg.nii.gz"):
    if len(aseg_path.stem.split("_")) == 3:
        arg = tuple(aseg_path.stem.split("_")[0:2])
    elif len(aseg_path.stem.split("_")) == 2:
        arg = aseg_path.stem.split("_")[0]
    aseg_split_path_dict[arg] = aseg_path

for t1_path in mslesseg_path.rglob("*_T1.nii.gz"):
    if len(t1_path.stem.split("_")) == 3:
        arg = tuple(t1_path.stem.split("_")[0:2])
    elif len(t1_path.stem.split("_")) == 2:
        arg = t1_path.stem.split("_")[0]
    t1_split_path_dict[arg] = t1_path

for split in aseg_split_path_dict.keys():
    if split not in t1_split_path_dict.keys():
        raise ValueError(f"Missing T1 file for key {split}")
    aseg_path = aseg_split_path_dict[split]
    t1_path = t1_split_path_dict[split]
    
    # CSV – écriture des mêmes infos
    if type(split) == tuple:
        csv_path = csv_folder_path / f"{split[0]}_{split[1]}_label.csv"
    elif type(split) == str:
        csv_path = csv_folder_path / f"{split}_label.csv"
    
    # Lecture des images
    aseg_img = sitk.ReadImage(aseg_path)
    t1_img   = sitk.ReadImage(t1_path)

    # LUT FreeSurfer ASEG
    freesurfer_aseg_labels = {
        0:  "Background",
        2:  "Left-Cerebral-White-Matter",
        3:  "Left-Cerebral-Cortex",
        4:  "Left-Lateral-Ventricle",
        5:  "Left-Inf-Lat-Vent",
        7:  "Left-Cerebellum-White-Matter",
        8:  "Left-Cerebellum-Cortex",
        10: "Left-Thalamus",
        11: "Left-Caudate",
        12: "Left-Putamen",
        13: "Left-Pallidum",
        17: "Left-Hippocampus",
        18: "Left-Amygdala",
        26: "Left-Accumbens-area",
        41: "Right-Cerebral-White-Matter",
        42: "Right-Cerebral-Cortex",
        43: "Right-Lateral-Ventricle",
        46: "Right-Cerebellum-White-Matter",
        47: "Right-Cerebellum-Cortex",
        49: "Right-Thalamus",
        50: "Right-Caudate",
        51: "Right-Putamen",
        52: "Right-Pallidum",
        53: "Right-Hippocampus",
        54: "Right-Amygdala",
        58: "Right-Accumbens-area"
    }

    def get_structure_name(label_value, parcellation="aseg"):
        if parcellation == "aseg":
            return freesurfer_aseg_labels.get(label_value, "Unknown")
        return "Unknown"


    # Sélection du label étudié
    label_value = 17  # exemple : hippocampe gauche

    binary = sitk.Equal(aseg_img, label_value)

    label_stats = sitk.LabelShapeStatisticsImageFilter()
    label_stats.Execute(binary)

    # Mesures
    volume_mm3  = label_stats.GetPhysicalSize(1)
    centroid_mm = label_stats.GetCentroid(1)
    bbox        = label_stats.GetBoundingBox(1)
    elongation  = label_stats.GetElongation(1)
    flatness    = label_stats.GetFlatness(1)

    structure_name = get_structure_name(label_value, parcellation="aseg")
    
    # PRINT
    print("=== Résultats ASEG ===")
    print(f"Label: {label_value}")
    print(f"Structure: {structure_name}")
    print(f"Volume: {volume_mm3:.1f} mm^3")
    print(f"Centroid (mm): {centroid_mm}")
    print(f"Bounding box (index, size): {bbox}")
    print(f"Elongation: {elongation:.3f}")
    print(f"Flatness: {flatness:.3f}")


    with open(csv_path, mode="w", newline="", encoding="utf-8") as csv_file:
        writer = csv.writer(csv_file)

        # En-tête
        writer.writerow([
            "label",
            "structure",
            "volume_mm3",
            "centroid_x_mm",
            "centroid_y_mm",
            "centroid_z_mm",
            "bbox_index_x",
            "bbox_index_y",
            "bbox_index_z",
            "bbox_size_x",
            "bbox_size_y",
            "bbox_size_z",
            "elongation",
            "flatness"
        ])

        # Données (copie exacte de ce qui est print)
        writer.writerow([
            label_value,
            structure_name,
            volume_mm3,
            centroid_mm[0],
            centroid_mm[1],
            centroid_mm[2],
            bbox[0],
            bbox[1],
            bbox[2],
            bbox[3],
            bbox[4],
            bbox[5],
            elongation,
            flatness
        ])

    print(f"\nCSV généré : {csv_path}")
# Out:
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 7723.0 mm^3
# Centroid (mm): (26.09504078725884, 18.65984720963357, -27.510682377314517)
# Bounding box (index, size): (99, 84, 23, 30, 44, 49)
# Elongation: 2.479
# Flatness: 2.362
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P10_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 10478.0 mm^3
# Centroid (mm): (23.503244894063755, 11.378507348730679, -39.55344531399122)
# Bounding box (index, size): (98, 87, 18, 29, 56, 38)
# Elongation: 2.470
# Flatness: 1.278
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P10_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 8396.0 mm^3
# Centroid (mm): (19.322534540257266, 28.43961410195331, -22.634349690328726)
# Bounding box (index, size): (95, 81, 22, 28, 38, 59)
# Elongation: 2.278
# Flatness: 2.724
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P11_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6897.0 mm^3
# Centroid (mm): (25.111642743221694, 22.69261997970132, -32.20994635348703)
# Bounding box (index, size): (100, 89, 9, 28, 31, 68)
# Elongation: 3.049
# Flatness: 2.201
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P11_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5084.0 mm^3
# Centroid (mm): (27.714988198269083, 30.60739575137687, -17.79130605822187)
# Bounding box (index, size): (100, 71, 41, 33, 50, 28)
# Elongation: 2.327
# Flatness: 2.065
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P12_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 9072.0 mm^3
# Centroid (mm): (26.781305114638442, 1.4195326278659621, -59.06867283950617)
# Bounding box (index, size): (101, 96, 2, 32, 58, 28)
# Elongation: 2.465
# Flatness: 1.369
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P12_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 10161.0 mm^3
# Centroid (mm): (26.226552504674743, 23.680641669127056, -48.363251648459794)
# Bounding box (index, size): (102, 64, 7, 29, 72, 42)
# Elongation: 2.857
# Flatness: 1.770
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P12_T3_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 9054.0 mm^3
# Centroid (mm): (28.940136956041528, -2.1805831676607, -36.75988513364259)
# Bounding box (index, size): (104, 99, 20, 30, 58, 31)
# Elongation: 2.593
# Flatness: 1.932
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P13_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5684.0 mm^3
# Centroid (mm): (28.47888810696692, 12.504574243490495, -20.960942997888807)
# Bounding box (index, size): (99, 88, 35, 34, 48, 33)
# Elongation: 2.436
# Flatness: 2.297
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P13_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6034.0 mm^3
# Centroid (mm): (26.03878024527677, 24.756049055353003, -17.579383493536625)
# Bounding box (index, size): (102, 81, 39, 28, 38, 40)
# Elongation: 2.159
# Flatness: 2.303
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P14_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 9978.0 mm^3
# Centroid (mm): (33.336740829825615, 28.684906794948887, -30.64762477450391)
# Bounding box (index, size): (100, 84, 10, 40, 30, 65)
# Elongation: 2.662
# Flatness: 2.092
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P14_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6079.0 mm^3
# Centroid (mm): (25.777101496956732, 23.69106760980425, -18.384438229972034)
# Bounding box (index, size): (101, 82, 38, 28, 38, 38)
# Elongation: 2.327
# Flatness: 1.827
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P14_T3_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6818.0 mm^3
# Centroid (mm): (26.446611909650926, 24.456438838369024, -18.481666177764737)
# Bounding box (index, size): (100, 82, 38, 30, 38, 38)
# Elongation: 2.041
# Flatness: 2.184
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P14_T4_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5281.0 mm^3
# Centroid (mm): (23.635296345389136, 7.160007574323046, -18.45142965347472)
# Bounding box (index, size): (98, 93, 40, 28, 47, 32)
# Elongation: 2.353
# Flatness: 2.592
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P15_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 3676.0 mm^3
# Centroid (mm): (23.22198041349293, 25.649075081610448, -52.30331882480958)
# Bounding box (index, size): (103, 92, 0, 22, 17, 46)
# Elongation: 2.602
# Flatness: 2.015
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P16_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 487.0 mm^3
# Centroid (mm): (18.819301848049278, -32.34086242299796, -69.71868583162218)
# Bounding box (index, size): (104, 151, 0, 13, 18, 9)
# Elongation: 1.765
# Flatness: 1.605
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P17_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5233.0 mm^3
# Centroid (mm): (24.35734760175808, 23.175616281291795, -14.254156315688896)
# Bounding box (index, size): (97, 81, 42, 31, 40, 35)
# Elongation: 2.193
# Flatness: 2.331
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P18_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 8299.0 mm^3
# Centroid (mm): (24.63622123147367, 8.96806844198096, -45.02494276418845)
# Bounding box (index, size): (98, 90, 10, 31, 54, 43)
# Elongation: 2.426
# Flatness: 2.136
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P19_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 7402.0 mm^3
# Centroid (mm): (27.619562280464734, 25.5409348824642, -29.618616590110783)
# Bounding box (index, size): (102, 83, 15, 30, 37, 58)
# Elongation: 2.625
# Flatness: 2.040
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P19_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6142.0 mm^3
# Centroid (mm): (22.617876913057643, 27.422989254314558, -17.27987626180397)
# Bounding box (index, size): (99, 81, 41, 29, 39, 35)
# Elongation: 2.178
# Flatness: 1.655
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P19_T3_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 7578.0 mm^3
# Centroid (mm): (24.66389548693587, 20.65597783056215, -29.57455793085247)
# Bounding box (index, size): (100, 85, 20, 30, 42, 51)
# Elongation: 2.407
# Flatness: 2.448
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P19_T4_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6225.0 mm^3
# Centroid (mm): (26.19052208835342, 24.57831325301204, -16.36176706827309)
# Bounding box (index, size): (101, 80, 39, 34, 42, 40)
# Elongation: 2.139
# Flatness: 2.544
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P1_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5839.0 mm^3
# Centroid (mm): (23.311525946223668, 20.487583490323686, -26.362904606953244)
# Bounding box (index, size): (100, 84, 28, 26, 42, 48)
# Elongation: 2.842
# Flatness: 2.134
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P1_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5487.0 mm^3
# Centroid (mm): (22.825952250774563, 14.905048295972293, -31.88992163295061)
# Bounding box (index, size): (99, 88, 23, 26, 43, 46)
# Elongation: 2.894
# Flatness: 2.245
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P1_T3_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6543.0 mm^3
# Centroid (mm): (29.3866727800703, 17.13006266238729, -19.458352437719704)
# Bounding box (index, size): (99, 89, 34, 36, 35, 45)
# Elongation: 2.112
# Flatness: 1.878
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P20_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5719.0 mm^3
# Centroid (mm): (24.817100891764298, 22.76429445707292, -13.406015037593988)
# Bounding box (index, size): (97, 83, 44, 31, 38, 37)
# Elongation: 1.964
# Flatness: 2.473
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P20_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 8613.0 mm^3
# Centroid (mm): (8.004179728317666, 30.26378729827006, -58.29664460698943)
# Bounding box (index, size): (83, 71, 0, 29, 48, 43)
# Elongation: 2.307
# Flatness: 1.470
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P20_T3_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6116.0 mm^3
# Centroid (mm): (23.77092871157619, 21.290058862001302, -16.971386527141924)
# Bounding box (index, size): (99, 87, 38, 28, 36, 41)
# Elongation: 2.356
# Flatness: 1.651
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P21_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6430.0 mm^3
# Centroid (mm): (24.173405909797822, 26.01477449455676, -13.46982892690513)
# Bounding box (index, size): (98, 76, 41, 30, 44, 42)
# Elongation: 2.331
# Flatness: 2.215
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P22_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 7325.0 mm^3
# Centroid (mm): (21.091058020477817, 23.024982935153588, -37.41747440273038)
# Bounding box (index, size): (95, 84, 9, 29, 35, 62)
# Elongation: 2.655
# Flatness: 2.225
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P22_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 4774.0 mm^3
# Centroid (mm): (22.126728110599075, 24.1891495601173, -12.909928780896522)
# Bounding box (index, size): (98, 83, 43, 27, 36, 36)
# Elongation: 2.299
# Flatness: 2.330
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P23_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5338.0 mm^3
# Centroid (mm): (25.51367553390783, 23.31865867366055, -13.235856125889846)
# Bounding box (index, size): (102, 81, 41, 27, 38, 39)
# Elongation: 2.227
# Flatness: 2.109
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P25_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5563.0 mm^3
# Centroid (mm): (23.712924680927557, 23.4127269458925, -14.504583857630777)
# Bounding box (index, size): (99, 83, 39, 30, 38, 43)
# Elongation: 2.455
# Flatness: 2.150
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P26_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5150.0 mm^3
# Centroid (mm): (24.660776699029128, 24.86776699029126, -12.778446601941745)
# Bounding box (index, size): (98, 81, 42, 30, 41, 39)
# Elongation: 2.251
# Flatness: 2.534
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P27_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 4898.0 mm^3
# Centroid (mm): (23.897713352388735, 22.3527970600245, -16.05104124132299)
# Bounding box (index, size): (98, 80, 41, 30, 45, 36)
# Elongation: 2.802
# Flatness: 1.857
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P28_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 4582.0 mm^3
# Centroid (mm): (22.909864687909206, 24.343081623745093, -12.931470973374076)
# Bounding box (index, size): (98, 80, 45, 28, 40, 35)
# Elongation: 2.573
# Flatness: 2.043
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P28_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6390.0 mm^3
# Centroid (mm): (25.200156494522687, 15.42363067292645, -26.32816901408451)
# Bounding box (index, size): (97, 84, 30, 31, 48, 44)
# Elongation: 2.199
# Flatness: 2.489
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P29_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5859.0 mm^3
# Centroid (mm): (23.161461000170675, 17.952210274790914, -21.904420549581843)
# Bounding box (index, size): (95, 87, 26, 32, 37, 62)
# Elongation: 3.521
# Flatness: 2.177
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P2_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6777.0 mm^3
# Centroid (mm): (22.91840047218534, 24.291869558801835, -12.147115242732774)
# Bounding box (index, size): (101, 83, 43, 26, 38, 40)
# Elongation: 2.171
# Flatness: 1.546
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P2_T4_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5609.0 mm^3
# Centroid (mm): (27.49598858976644, 2.969691567124258, -32.6660723836691)
# Bounding box (index, size): (103, 89, 27, 27, 61, 28)
# Elongation: 2.956
# Flatness: 2.176
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P30_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6651.0 mm^3
# Centroid (mm): (25.485340550293188, 15.18884378288979, -33.45271387761239)
# Bounding box (index, size): (101, 87, 23, 28, 44, 39)
# Elongation: 2.191
# Flatness: 2.203
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P31_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 7015.0 mm^3
# Centroid (mm): (25.642337847469705, 14.419672131147536, -35.557377049180324)
# Bounding box (index, size): (102, 88, 21, 27, 44, 38)
# Elongation: 2.167
# Flatness: 2.251
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P31_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5322.0 mm^3
# Centroid (mm): (26.082299887260433, 23.91657271702367, -14.027433295753475)
# Bounding box (index, size): (100, 80, 42, 31, 39, 39)
# Elongation: 2.144
# Flatness: 2.391
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P32_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5785.0 mm^3
# Centroid (mm): (24.065341400172855, 15.918755401901464, -32.5780466724287)
# Bounding box (index, size): (101, 83, 17, 25, 47, 51)
# Elongation: 3.150
# Flatness: 2.161
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P33_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6091.0 mm^3
# Centroid (mm): (23.424396650796254, 17.470366113938596, -27.83500246264981)
# Bounding box (index, size): (101, 82, 22, 27, 47, 50)
# Elongation: 3.133
# Flatness: 1.992
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P33_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5320.0 mm^3
# Centroid (mm): (25.984962406015043, 20.437969924812023, -15.583834586466168)
# Bounding box (index, size): (100, 83, 38, 30, 41, 41)
# Elongation: 2.139
# Flatness: 2.444
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P34_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6212.0 mm^3
# Centroid (mm): (26.05135222150676, 20.16403734707019, -31.76094655505473)
# Bounding box (index, size): (100, 86, 19, 30, 36, 48)
# Elongation: 2.281
# Flatness: 2.187
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P35_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6839.0 mm^3
# Centroid (mm): (23.672612955110395, 18.499926889896187, -35.22166983477116)
# Bounding box (index, size): (99, 85, 14, 29, 43, 54)
# Elongation: 2.864
# Flatness: 2.028
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P36_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6576.0 mm^3
# Centroid (mm): (24.893400243309003, 21.55869829683698, -15.481295620437955)
# Bounding box (index, size): (101, 84, 39, 28, 39, 40)
# Elongation: 2.148
# Flatness: 1.414
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P37_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6102.0 mm^3
# Centroid (mm): (25.672402490986556, 15.92903965912815, -21.279088823336608)
# Bounding box (index, size): (101, 88, 31, 27, 44, 41)
# Elongation: 2.778
# Flatness: 1.770
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P38_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6436.0 mm^3
# Centroid (mm): (20.419204474829087, 30.568054692355503, -29.85627719080174)
# Bounding box (index, size): (100, 78, 27, 24, 45, 33)
# Elongation: 2.082
# Flatness: 1.484
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P39_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6481.0 mm^3
# Centroid (mm): (24.843696960345625, 18.494676747415525, -34.36213547292085)
# Bounding box (index, size): (100, 86, 16, 28, 42, 53)
# Elongation: 2.593
# Flatness: 2.320
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P3_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5011.0 mm^3
# Centroid (mm): (24.653362602274996, 22.331869886250246, -18.326282179205748)
# Bounding box (index, size): (101, 83, 38, 26, 40, 41)
# Elongation: 2.272
# Flatness: 2.564
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P3_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 7004.0 mm^3
# Centroid (mm): (22.774414620217016, 13.641490576813254, -34.27826956025128)
# Bounding box (index, size): (100, 86, 26, 27, 50, 33)
# Elongation: 2.438
# Flatness: 1.709
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P3_T3_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6642.0 mm^3
# Centroid (mm): (23.262119843420663, 24.920806985847634, -18.245408009635653)
# Bounding box (index, size): (97, 87, 25, 28, 32, 66)
# Elongation: 3.365
# Flatness: 1.980
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P3_T4_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6453.0 mm^3
# Centroid (mm): (25.323570432357045, 22.829071749573842, -30.145048814504882)
# Bounding box (index, size): (98, 82, 20, 30, 40, 50)
# Elongation: 2.661
# Flatness: 2.515
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P40_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5506.0 mm^3
# Centroid (mm): (25.14693062114057, 13.413367235742825, -31.822738830366873)
# Bounding box (index, size): (100, 89, 23, 27, 41, 50)
# Elongation: 2.596
# Flatness: 2.307
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P41_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5450.0 mm^3
# Centroid (mm): (25.04477064220184, 23.50311926605505, -15.080366972477066)
# Bounding box (index, size): (99, 82, 41, 29, 38, 38)
# Elongation: 2.192
# Flatness: 2.428
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P42_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5671.0 mm^3
# Centroid (mm): (24.32463410333274, 23.970728266619645, -13.01128548756833)
# Bounding box (index, size): (98, 85, 42, 29, 35, 39)
# Elongation: 2.069
# Flatness: 2.296
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P43_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 7176.0 mm^3
# Centroid (mm): (25.971850613154956, 17.721014492753625, -27.557552954292085)
# Bounding box (index, size): (101, 85, 22, 30, 45, 54)
# Elongation: 2.549
# Flatness: 2.323
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P44_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5984.0 mm^3
# Centroid (mm): (24.956550802139034, 10.935661764705884, -27.205548128342244)
# Bounding box (index, size): (101, 91, 26, 28, 45, 44)
# Elongation: 2.641
# Flatness: 2.351
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P45_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 4708.0 mm^3
# Centroid (mm): (25.942650807136786, 25.14592183517418, -10.721537807986408)
# Bounding box (index, size): (103, 80, 45, 26, 40, 39)
# Elongation: 2.202
# Flatness: 2.603
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P46_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5835.0 mm^3
# Centroid (mm): (23.343273350471293, 24.26461011139675, -15.618851756640957)
# Bounding box (index, size): (97, 83, 38, 33, 40, 38)
# Elongation: 2.305
# Flatness: 2.352
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P47_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6855.0 mm^3
# Centroid (mm): (29.40612691466083, 22.21371261852663, -36.52472647702407)
# Bounding box (index, size): (102, 83, 13, 30, 39, 51)
# Elongation: 2.386
# Flatness: 2.502
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P48_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 4947.0 mm^3
# Centroid (mm): (22.903982211441274, 16.459874671518094, -15.233474833232265)
# Bounding box (index, size): (98, 86, 39, 30, 45, 42)
# Elongation: 2.522
# Flatness: 2.590
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P49_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6093.0 mm^3
# Centroid (mm): (24.91137370753323, 20.93894633185623, -23.61710159199081)
# Bounding box (index, size): (100, 86, 29, 28, 37, 46)
# Elongation: 2.425
# Flatness: 2.233
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P4_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 3556.0 mm^3
# Centroid (mm): (25.24071991001125, 39.50337457817773, -62.375421822272216)
# Bounding box (index, size): (101, 78, 0, 28, 21, 26)
# Elongation: 1.524
# Flatness: 1.719
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P50_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 10384.0 mm^3
# Centroid (mm): (24.1890408320493, 11.634148690292761, -59.869029275808934)
# Bounding box (index, size): (99, 84, 0, 30, 61, 32)
# Elongation: 2.638
# Flatness: 1.981
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P50_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 8208.0 mm^3
# Centroid (mm): (22.962353801169584, 20.24817251461988, -27.02351364522417)
# Bounding box (index, size): (98, 85, 22, 28, 40, 52)
# Elongation: 2.907
# Flatness: 1.224
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P51_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5777.0 mm^3
# Centroid (mm): (24.47100571230743, 14.879176042928862, -24.042063354682362)
# Bounding box (index, size): (98, 86, 32, 31, 48, 34)
# Elongation: 2.286
# Flatness: 2.499
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P51_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5880.0 mm^3
# Centroid (mm): (27.242857142857147, 24.871768707483, -16.018537414965984)
# Bounding box (index, size): (100, 81, 39, 30, 40, 37)
# Elongation: 2.082
# Flatness: 2.518
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P52_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 8045.0 mm^3
# Centroid (mm): (26.872840273461776, 15.860285891858297, -32.71771286513362)
# Bounding box (index, size): (100, 85, 17, 31, 45, 49)
# Elongation: 2.815
# Flatness: 1.681
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P52_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 7376.0 mm^3
# Centroid (mm): (24.3777114967462, 21.604663774403477, -30.833920824295014)
# Bounding box (index, size): (99, 80, 23, 29, 46, 43)
# Elongation: 2.667
# Flatness: 1.887
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P53_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6183.0 mm^3
# Centroid (mm): (24.38589681384441, 27.44282710658257, -15.99514798641436)
# Bounding box (index, size): (98, 77, 41, 31, 43, 36)
# Elongation: 2.358
# Flatness: 1.891
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P53_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 4809.0 mm^3
# Centroid (mm): (24.13599500935746, 22.489498856311087, -14.064878353087963)
# Bounding box (index, size): (100, 84, 43, 27, 35, 36)
# Elongation: 2.078
# Flatness: 2.435
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P54_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6100.0 mm^3
# Centroid (mm): (25.813606557377042, 23.744918032786885, -14.389508196721309)
# Bounding box (index, size): (102, 83, 40, 28, 37, 42)
# Elongation: 2.069
# Flatness: 2.283
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P55_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5783.0 mm^3
# Centroid (mm): (21.94068822410513, 21.94985301746499, -24.77226353103925)
# Bounding box (index, size): (97, 84, 29, 29, 39, 43)
# Elongation: 2.735
# Flatness: 1.998
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P56_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 13548.0 mm^3
# Centroid (mm): (34.13573959255979, 21.04495128432241, -45.1108650723354)
# Bounding box (index, size): (105, 89, 3, 38, 35, 62)
# Elongation: 2.018
# Flatness: 1.817
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P57_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 7489.0 mm^3
# Centroid (mm): (20.766991587661906, 25.961276538923755, -53.16130324475898)
# Bounding box (index, size): (98, 77, 0, 23, 45, 47)
# Elongation: 3.041
# Flatness: 1.599
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P58_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5320.0 mm^3
# Centroid (mm): (26.263909774436087, 24.533646616541347, -11.753759398496243)
# Bounding box (index, size): (101, 80, 45, 30, 40, 36)
# Elongation: 2.079
# Flatness: 2.489
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P59_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6065.0 mm^3
# Centroid (mm): (23.068920032976095, 19.787139323990104, -27.470239076669415)
# Bounding box (index, size): (99, 82, 25, 26, 44, 46)
# Elongation: 2.966
# Flatness: 2.025
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P5_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5864.0 mm^3
# Centroid (mm): (22.698840381991815, 16.839870395634378, -28.52387448840382)
# Bounding box (index, size): (98, 86, 24, 32, 42, 45)
# Elongation: 2.381
# Flatness: 2.434
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P5_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 7910.0 mm^3
# Centroid (mm): (23.16523388116309, 9.357901390644756, -22.469532237673832)
# Bounding box (index, size): (99, 87, 36, 28, 53, 29)
# Elongation: 2.133
# Flatness: 1.518
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P60_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5579.0 mm^3
# Centroid (mm): (25.194120810181033, 22.512995160423017, -11.442731672342717)
# Bounding box (index, size): (99, 85, 42, 32, 35, 37)
# Elongation: 1.755
# Flatness: 2.904
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P61_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6458.0 mm^3
# Centroid (mm): (25.447816661505115, 16.06039021368845, -33.47352121399814)
# Bounding box (index, size): (100, 86, 21, 28, 45, 48)
# Elongation: 2.367
# Flatness: 2.362
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P62_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6220.0 mm^3
# Centroid (mm): (25.891639871382637, 16.742604501607715, -33.04083601286174)
# Bounding box (index, size): (101, 88, 16, 28, 39, 53)
# Elongation: 2.474
# Flatness: 2.612
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P63_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6524.0 mm^3
# Centroid (mm): (24.281422440220723, 6.4120171673819755, -38.75352544451257)
# Bounding box (index, size): (99, 87, 14, 31, 56, 47)
# Elongation: 2.446
# Flatness: 2.353
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P64_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 4637.0 mm^3
# Centroid (mm): (25.04119042484365, 25.813241319818843, -14.582704334699159)
# Bounding box (index, size): (102, 81, 40, 28, 39, 38)
# Elongation: 2.420
# Flatness: 2.297
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P65_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6429.0 mm^3
# Centroid (mm): (22.169233162233624, 26.966713330222433, -13.256494011510341)
# Bounding box (index, size): (99, 76, 43, 26, 45, 39)
# Elongation: 2.933
# Flatness: 1.255
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P66_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 8140.0 mm^3
# Centroid (mm): (24.267813267813267, 24.018304668304665, -17.742137592137595)
# Bounding box (index, size): (96, 80, 32, 32, 41, 48)
# Elongation: 2.265
# Flatness: 2.337
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P67_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5641.0 mm^3
# Centroid (mm): (26.57542988831767, 24.444424747385213, -12.070909413224605)
# Bounding box (index, size): (101, 79, 45, 30, 43, 35)
# Elongation: 2.105
# Flatness: 2.462
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P68_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 7207.0 mm^3
# Centroid (mm): (23.80241431941168, 10.046066324406823, -31.71444429027335)
# Bounding box (index, size): (99, 86, 23, 29, 55, 41)
# Elongation: 2.791
# Flatness: 1.897
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P69_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5824.0 mm^3
# Centroid (mm): (25.66260302197803, 10.810439560439562, -24.35113324175824)
# Bounding box (index, size): (97, 91, 33, 34, 43, 36)
# Elongation: 2.124
# Flatness: 2.738
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P6_T3_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6280.0 mm^3
# Centroid (mm): (25.0656050955414, 26.929777070063693, -10.588057324840761)
# Bounding box (index, size): (101, 78, 47, 28, 43, 35)
# Elongation: 2.246
# Flatness: 1.996
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P70_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5340.0 mm^3
# Centroid (mm): (25.25187265917603, 23.869475655430705, -16.223220973782773)
# Bounding box (index, size): (101, 77, 38, 28, 46, 39)
# Elongation: 2.563
# Flatness: 2.617
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P71_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 6420.0 mm^3
# Centroid (mm): (22.637383177570086, 16.43707165109035, -30.69096573208723)
# Bounding box (index, size): (98, 85, 24, 29, 45, 42)
# Elongation: 2.416
# Flatness: 2.348
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P72_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 8293.0 mm^3
# Centroid (mm): (25.19257204871579, 22.70830821174485, -30.3507777643796)
# Bounding box (index, size): (99, 83, 16, 32, 41, 55)
# Elongation: 2.589
# Flatness: 2.117
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P73_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5065.0 mm^3
# Centroid (mm): (24.73682132280355, 23.47423494570583, -13.311352418558734)
# Bounding box (index, size): (102, 80, 43, 26, 42, 41)
# Elongation: 2.382
# Flatness: 2.359
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P74_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 8646.0 mm^3
# Centroid (mm): (24.87531806615776, 14.960791117279669, -31.722068008327547)
# Bounding box (index, size): (100, 84, 15, 29, 47, 56)
# Elongation: 2.792
# Flatness: 1.891
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P75_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 8339.0 mm^3
# Centroid (mm): (24.642283247391774, 27.65691329895671, -40.54299076627893)
# Bounding box (index, size): (90, 81, 0, 41, 37, 61)
# Elongation: 2.282
# Flatness: 2.740
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P7_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 7688.0 mm^3
# Centroid (mm): (24.39399063475547, -0.9797086368366337, -45.63293444328824)
# Bounding box (index, size): (98, 93, 13, 31, 62, 38)
# Elongation: 3.020
# Flatness: 1.793
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P8_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 8234.0 mm^3
# Centroid (mm): (29.164925916929803, -7.020403206218134, -30.5088656788924)
# Bounding box (index, size): (105, 95, 27, 27, 67, 38)
# Elongation: 3.331
# Flatness: 1.643
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P8_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 7413.0 mm^3
# Centroid (mm): (24.856738162687165, 30.272224470524748, -36.44287063267233)
# Bounding box (index, size): (101, 76, 11, 29, 38, 58)
# Elongation: 3.111
# Flatness: 1.877
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P9_T1_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 5507.0 mm^3
# Centroid (mm): (23.005447612130013, 17.59615035409479, -30.37534047575813)
# Bounding box (index, size): (100, 87, 20, 26, 41, 51)
# Elongation: 3.172
# Flatness: 1.978
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P9_T2_label.csv
# === Résultats ASEG ===
# Label: 17
# Structure: Left-Hippocampus
# Volume: 8043.0 mm^3
# Centroid (mm): (24.342906875543946, 26.463508641054332, -43.7668780305856)
# Bounding box (index, size): (100, 75, 6, 30, 45, 54)
# Elongation: 2.952
# Flatness: 1.807
#
# CSV généré : c:\Users\zhong\Documents\GitHub\SIR-project\data\09_label_csv\P9_T3_label.csv
