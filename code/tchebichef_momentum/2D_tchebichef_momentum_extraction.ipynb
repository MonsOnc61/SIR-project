# %% [markdown]
# ### Extraction des moments de tchebichef des lésion en 2D (01 -> 14)

# %%
from pathlib import Path
import SimpleITK as sitk
import numpy as np
import csv

data_path = Path.cwd().parent.parent / "data"

tchbichef_2d_dir_path = data_path / "14_2D_momentum_extraction_csv_dir"
if not tchbichef_2d_dir_path.exists():
    tchbichef_2d_dir_path.mkdir(parents = True, exist_ok = True)

# A CHOISIR:
ORDRE_CIBLE = 10 # 10 * 10 = 100 coefficients

# %%
def tchebichef_polynomials(N, order):
    M = np.zeros((order, N))
    x = np.arange(N)
    M[0, :] = 1.0
    if order > 1: M[1, :] = (2.0 * x - N + 1.0) / N
    for p in range(2, order):
        M[p, :] = ((2.0*p-1.0)*(2.0*x-N+1.0)/(p*N))*M[p-1,:] - ((p-1.0)/p)*(1.0-((p-1.0)**2/(N**2)))*M[p-2,:]
    return M

def calculate_rho(N, order):
    rho = np.zeros(order); rho[0] = N
    for p in range(1, order): rho[p] = (N**2-p**2)/(N**2) * (2*p-1)/(2*p+1) * rho[p-1]
    return rho

def decompose_2d(image, requested_order):
    H, W = image.shape
    actual_order_h, actual_order_w = min(requested_order, H), min(requested_order, W)
    M_h = tchebichef_polynomials(H, actual_order_h)
    M_w = tchebichef_polynomials(W, actual_order_w)
    rho_h, rho_w = calculate_rho(H, actual_order_h), calculate_rho(W, actual_order_w)
    T_raw = M_h @ image @ M_w.T
    C_pq = 1.0 / np.outer(rho_h, rho_w)
    T_pq_small = T_raw * C_pq
    T_final = np.zeros((requested_order, requested_order))
    T_final[:actual_order_h, :actual_order_w] = T_pq_small
    return np.round(T_final, 3) # Arrondi à 3 décimales dès le calcul

def reconstruct_2d(moments, shape_originale):
    H, W = shape_originale
    order = moments.shape[0]
    M_h = tchebichef_polynomials(H, order)
    M_w = tchebichef_polynomials(W, order)
    return M_h.T @ moments @ M_w

# %%
"""
01 -> 14
Ce script prend environ 2 minutes
Extraction des moments 2D d'images médicales
"""

mslesseg_path = data_path / "01_MSLesSeg_Dataset"

# Parcours de tous les patients et leurs sous-dossiers
for mask_path in mslesseg_path.rglob("*_MASK.nii.gz"):
    arg = mask_path.stem.split("_")
    if len(arg) == 3:
        patient_id, timepoint = arg[0], arg[1]
    elif len(arg) == 2:
        patient_id, timepoint = arg[0], None
    patient_dir = mask_path.parent

    # Chargement du masque et identification des lésions
    mask_sitk = sitk.ReadImage(mask_path)
    mask_bin = sitk.Cast(mask_sitk > 0, sitk.sitkUInt8)
    lesion_cc = sitk.RelabelComponent(sitk.ConnectedComponent(mask_bin))  # L1 = plus grosse
    mask_arr = sitk.GetArrayFromImage(lesion_cc)
    num_lesions = int(mask_arr.max())

    t1_path = list(patient_dir.glob("*_T1.nii.gz"))[0]
    t2_path = list(patient_dir.glob("*_T2.nii.gz"))[0]
    flair_path = list(patient_dir.glob("*_FLAIR.nii.gz"))[0]

    for modality_path in [t1_path, t2_path, flair_path]:
        modality_name = (modality_path.stem.split("_")[-1]).split(".")[0]
        img_arr = sitk.GetArrayFromImage(sitk.ReadImage(modality_path))

        print(f"Processing: {patient_id} {timepoint} {modality_name}: {num_lesions} lésions")

        for l_id in range(1, num_lesions + 1):
            lesion_mask_3d = (mask_arr == l_id)
            areas = lesion_mask_3d.sum(axis=(1, 2))
            best_z = np.argmax(areas)

            # Extraction ROI
            slice_mask = lesion_mask_3d[best_z, :, :]
            ys, xs = np.where(slice_mask)
            if len(ys) < 2 or len(xs) < 2:
                continue

            roi = img_arr[best_z, ys.min():ys.max()+1, xs.min():xs.max()+1] * slice_mask[ys.min():ys.max()+1, xs.min():xs.max()+1]

            # Normalisation et décomposition
            max_v = np.max(roi)
            roi_norm = roi / max_v if max_v > 0 else roi

            moments = decompose_2d(roi_norm, ORDRE_CIBLE)

            # Sauvegarde CSV
            if len(arg) == 3:
                csv_name = f"{patient_id}_{timepoint}_{modality_name}_L{l_id}_Cheby.csv"
            elif len(arg) == 2:
                csv_name = f"{patient_id}_{modality_name}_L{l_id}_Cheby.csv"
            csv_file = tchbichef_2d_dir_path / csv_name
            
            with csv_file.open("w", newline="") as f:
                csv.writer(f).writerows(moments)

print("\n[SUCCÈS] Toutes les lésions de tous les patients ont été extraites.")
# Out:
# Processing: P54 None T1: 5 lésions
# Processing: P54 None T2: 5 lésions
# Processing: P54 None FLAIR: 5 lésions
# Processing: P55 None T1: 37 lésions
# Processing: P55 None T2: 37 lésions
# Processing: P55 None FLAIR: 37 lésions
# Processing: P56 None T1: 4 lésions
# Processing: P56 None T2: 4 lésions
# Processing: P56 None FLAIR: 4 lésions
# Processing: P57 None T1: 113 lésions
# Processing: P57 None T2: 113 lésions
# Processing: P57 None FLAIR: 113 lésions
# Processing: P58 None T1: 43 lésions
# Processing: P58 None T2: 43 lésions
# Processing: P58 None FLAIR: 43 lésions
# Processing: P59 None T1: 15 lésions
# Processing: P59 None T2: 15 lésions
# Processing: P59 None FLAIR: 15 lésions
# Processing: P60 None T1: 26 lésions
# Processing: P60 None T2: 26 lésions
# Processing: P60 None FLAIR: 26 lésions
# Processing: P61 None T1: 13 lésions
# Processing: P61 None T2: 13 lésions
# Processing: P61 None FLAIR: 13 lésions
# Processing: P62 None T1: 52 lésions
# Processing: P62 None T2: 52 lésions
# Processing: P62 None FLAIR: 52 lésions
# Processing: P63 None T1: 12 lésions
# Processing: P63 None T2: 12 lésions
# Processing: P63 None FLAIR: 12 lésions
# Processing: P64 None T1: 33 lésions
# Processing: P64 None T2: 33 lésions
# Processing: P64 None FLAIR: 33 lésions
# Processing: P65 None T1: 193 lésions
# Processing: P65 None T2: 193 lésions
# Processing: P65 None FLAIR: 193 lésions
# Processing: P66 None T1: 59 lésions
# Processing: P66 None T2: 59 lésions
# Processing: P66 None FLAIR: 59 lésions
# Processing: P67 None T1: 77 lésions
# Processing: P67 None T2: 77 lésions
# Processing: P67 None FLAIR: 77 lésions
# Processing: P68 None T1: 8 lésions
# Processing: P68 None T2: 8 lésions
# Processing: P68 None FLAIR: 8 lésions
# Processing: P69 None T1: 25 lésions
# Processing: P69 None T2: 25 lésions
# Processing: P69 None FLAIR: 25 lésions
# Processing: P70 None T1: 22 lésions
# Processing: P70 None T2: 22 lésions
# Processing: P70 None FLAIR: 22 lésions
# Processing: P71 None T1: 19 lésions
# Processing: P71 None T2: 19 lésions
# Processing: P71 None FLAIR: 19 lésions
# Processing: P72 None T1: 15 lésions
# Processing: P72 None T2: 15 lésions
# Processing: P72 None FLAIR: 15 lésions
# Processing: P73 None T1: 35 lésions
# Processing: P73 None T2: 35 lésions
# Processing: P73 None FLAIR: 35 lésions
# Processing: P74 None T1: 31 lésions
# Processing: P74 None T2: 31 lésions
# Processing: P74 None FLAIR: 31 lésions
# Processing: P75 None T1: 70 lésions
# Processing: P75 None T2: 70 lésions
# Processing: P75 None FLAIR: 70 lésions
# Processing: P1 T1 T1: 18 lésions
# Processing: P1 T1 T2: 18 lésions
# Processing: P1 T1 FLAIR: 18 lésions
# Processing: P1 T2 T1: 18 lésions
# Processing: P1 T2 T2: 18 lésions
# Processing: P1 T2 FLAIR: 18 lésions
# Processing: P1 T3 T1: 14 lésions
# Processing: P1 T3 T2: 14 lésions
# Processing: P1 T3 FLAIR: 14 lésions
# Processing: P10 T1 T1: 35 lésions
# Processing: P10 T1 T2: 35 lésions
# Processing: P10 T1 FLAIR: 35 lésions
# Processing: P10 T2 T1: 32 lésions
# Processing: P10 T2 T2: 32 lésions
# Processing: P10 T2 FLAIR: 32 lésions
# Processing: P11 T1 T1: 15 lésions
# Processing: P11 T1 T2: 15 lésions
# Processing: P11 T1 FLAIR: 15 lésions
# Processing: P11 T2 T1: 10 lésions
# Processing: P11 T2 T2: 10 lésions
# Processing: P11 T2 FLAIR: 10 lésions
# Processing: P12 T1 T1: 36 lésions
# Processing: P12 T1 T2: 36 lésions
# Processing: P12 T1 FLAIR: 36 lésions
# Processing: P12 T2 T1: 42 lésions
# Processing: P12 T2 T2: 42 lésions
# Processing: P12 T2 FLAIR: 42 lésions
# Processing: P12 T3 T1: 44 lésions
# Processing: P12 T3 T2: 44 lésions
# Processing: P12 T3 FLAIR: 44 lésions
# Processing: P12 T4 T1: 43 lésions
# Processing: P12 T4 T2: 43 lésions
# Processing: P12 T4 FLAIR: 43 lésions
# Processing: P13 T1 T1: 39 lésions
# Processing: P13 T1 T2: 39 lésions
# Processing: P13 T1 FLAIR: 39 lésions
# Processing: P13 T2 T1: 61 lésions
# Processing: P13 T2 T2: 61 lésions
# Processing: P13 T2 FLAIR: 61 lésions
# Processing: P14 T1 T1: 17 lésions
# Processing: P14 T1 T2: 17 lésions
# Processing: P14 T1 FLAIR: 17 lésions
# Processing: P14 T2 T1: 17 lésions
# Processing: P14 T2 T2: 17 lésions
# Processing: P14 T2 FLAIR: 17 lésions
# Processing: P14 T3 T1: 29 lésions
# Processing: P14 T3 T2: 29 lésions
# Processing: P14 T3 FLAIR: 29 lésions
# Processing: P14 T4 T1: 28 lésions
# Processing: P14 T4 T2: 28 lésions
# Processing: P14 T4 FLAIR: 28 lésions
# Processing: P15 T1 T1: 6 lésions
# Processing: P15 T1 T2: 6 lésions
# Processing: P15 T1 FLAIR: 6 lésions
# Processing: P16 T1 T1: 4 lésions
# Processing: P16 T1 T2: 4 lésions
# Processing: P16 T1 FLAIR: 4 lésions
# Processing: P17 T1 T1: 11 lésions
# Processing: P17 T1 T2: 11 lésions
# Processing: P17 T1 FLAIR: 11 lésions
# Processing: P18 T1 T1: 3 lésions
# Processing: P18 T1 T2: 3 lésions
# Processing: P18 T1 FLAIR: 3 lésions
# Processing: P19 T1 T1: 61 lésions
# Processing: P19 T1 T2: 61 lésions
# Processing: P19 T1 FLAIR: 61 lésions
# Processing: P19 T2 T1: 56 lésions
# Processing: P19 T2 T2: 56 lésions
# Processing: P19 T2 FLAIR: 56 lésions
# Processing: P19 T3 T1: 64 lésions
# Processing: P19 T3 T2: 64 lésions
# Processing: P19 T3 FLAIR: 64 lésions
# Processing: P19 T4 T1: 26 lésions
# Processing: P19 T4 T2: 26 lésions
# Processing: P19 T4 FLAIR: 26 lésions
# Processing: P2 T1 T1: 16 lésions
# Processing: P2 T1 T2: 16 lésions
# Processing: P2 T1 FLAIR: 16 lésions
# Processing: P2 T2 T1: 20 lésions
# Processing: P2 T2 T2: 20 lésions
# Processing: P2 T2 FLAIR: 20 lésions
# Processing: P2 T3 T1: 14 lésions
# Processing: P2 T3 T2: 14 lésions
# Processing: P2 T3 FLAIR: 14 lésions
# Processing: P2 T4 T1: 18 lésions
# Processing: P2 T4 T2: 18 lésions
# Processing: P2 T4 FLAIR: 18 lésions
# Processing: P20 T1 T1: 8 lésions
# Processing: P20 T1 T2: 8 lésions
# Processing: P20 T1 FLAIR: 8 lésions
# Processing: P20 T2 T1: 26 lésions
# Processing: P20 T2 T2: 26 lésions
# Processing: P20 T2 FLAIR: 26 lésions
# Processing: P20 T3 T1: 13 lésions
# Processing: P20 T3 T2: 13 lésions
# Processing: P20 T3 FLAIR: 13 lésions
# Processing: P21 T1 T1: 13 lésions
# Processing: P21 T1 T2: 13 lésions
# Processing: P21 T1 FLAIR: 13 lésions
# Processing: P22 T1 T1: 21 lésions
# Processing: P22 T1 T2: 21 lésions
# Processing: P22 T1 FLAIR: 21 lésions
# Processing: P22 T2 T1: 21 lésions
# Processing: P22 T2 T2: 21 lésions
# Processing: P22 T2 FLAIR: 21 lésions
# Processing: P23 T1 T1: 20 lésions
# Processing: P23 T1 T2: 20 lésions
# Processing: P23 T1 FLAIR: 20 lésions
# Processing: P24 T1 T1: 57 lésions
# Processing: P24 T1 T2: 57 lésions
# Processing: P24 T1 FLAIR: 57 lésions
# Processing: P25 T1 T1: 6 lésions
# Processing: P25 T1 T2: 6 lésions
# Processing: P25 T1 FLAIR: 6 lésions
# Processing: P26 T1 T1: 43 lésions
# Processing: P26 T1 T2: 43 lésions
# Processing: P26 T1 FLAIR: 43 lésions
# Processing: P27 T1 T1: 25 lésions
# Processing: P27 T1 T2: 25 lésions
# Processing: P27 T1 FLAIR: 25 lésions
# Processing: P28 T1 T1: 8 lésions
# Processing: P28 T1 T2: 8 lésions
# Processing: P28 T1 FLAIR: 8 lésions
# Processing: P28 T2 T1: 21 lésions
# Processing: P28 T2 T2: 21 lésions
# Processing: P28 T2 FLAIR: 21 lésions
# Processing: P29 T1 T1: 27 lésions
# Processing: P29 T1 T2: 27 lésions
# Processing: P29 T1 FLAIR: 27 lésions
# Processing: P3 T1 T1: 42 lésions
# Processing: P3 T1 T2: 42 lésions
# Processing: P3 T1 FLAIR: 42 lésions
# Processing: P3 T2 T1: 16 lésions
# Processing: P3 T2 T2: 16 lésions
# Processing: P3 T2 FLAIR: 16 lésions
# Processing: P3 T3 T1: 26 lésions
# Processing: P3 T3 T2: 26 lésions
# Processing: P3 T3 FLAIR: 26 lésions
# Processing: P3 T4 T1: 25 lésions
# Processing: P3 T4 T2: 25 lésions
# Processing: P3 T4 FLAIR: 25 lésions
# Processing: P30 T1 T1: 6 lésions
# Processing: P30 T1 T2: 6 lésions
# Processing: P30 T1 FLAIR: 6 lésions
# Processing: P31 T1 T1: 29 lésions
# Processing: P31 T1 T2: 29 lésions
# Processing: P31 T1 FLAIR: 29 lésions
# Processing: P31 T2 T1: 31 lésions
# Processing: P31 T2 T2: 31 lésions
# Processing: P31 T2 FLAIR: 31 lésions
# Processing: P32 T1 T1: 12 lésions
# Processing: P32 T1 T2: 12 lésions
# Processing: P32 T1 FLAIR: 12 lésions
# Processing: P33 T1 T1: 44 lésions
# Processing: P33 T1 T2: 44 lésions
# Processing: P33 T1 FLAIR: 44 lésions
# Processing: P33 T2 T1: 31 lésions
# Processing: P33 T2 T2: 31 lésions
# Processing: P33 T2 FLAIR: 31 lésions
# Processing: P34 T1 T1: 32 lésions
# Processing: P34 T1 T2: 32 lésions
# Processing: P34 T1 FLAIR: 32 lésions
# Processing: P35 T1 T1: 109 lésions
# Processing: P35 T1 T2: 109 lésions
# Processing: P35 T1 FLAIR: 109 lésions
# Processing: P36 T1 T1: 79 lésions
# Processing: P36 T1 T2: 79 lésions
# Processing: P36 T1 FLAIR: 79 lésions
# Processing: P37 T1 T1: 16 lésions
# Processing: P37 T1 T2: 16 lésions
# Processing: P37 T1 FLAIR: 16 lésions
# Processing: P38 T1 T1: 111 lésions
# Processing: P38 T1 T2: 111 lésions
# Processing: P38 T1 FLAIR: 111 lésions
# Processing: P39 T1 T1: 35 lésions
# Processing: P39 T1 T2: 35 lésions
# Processing: P39 T1 FLAIR: 35 lésions
# Processing: P4 T1 T1: 22 lésions
# Processing: P4 T1 T2: 22 lésions
# Processing: P4 T1 FLAIR: 22 lésions
# Processing: P4 T2 T1: 28 lésions
# Processing: P4 T2 T2: 28 lésions
# Processing: P4 T2 FLAIR: 28 lésions
# Processing: P4 T3 T1: 21 lésions
# Processing: P4 T3 T2: 21 lésions
# Processing: P4 T3 FLAIR: 21 lésions
# Processing: P40 T1 T1: 23 lésions
# Processing: P40 T1 T2: 23 lésions
# Processing: P40 T1 FLAIR: 23 lésions
# Processing: P41 T1 T1: 10 lésions
# Processing: P41 T1 T2: 10 lésions
# Processing: P41 T1 FLAIR: 10 lésions
# Processing: P42 T1 T1: 44 lésions
# Processing: P42 T1 T2: 44 lésions
# Processing: P42 T1 FLAIR: 44 lésions
# Processing: P43 T1 T1: 40 lésions
# Processing: P43 T1 T2: 40 lésions
# Processing: P43 T1 FLAIR: 40 lésions
# Processing: P44 T1 T1: 11 lésions
# Processing: P44 T1 T2: 11 lésions
# Processing: P44 T1 FLAIR: 11 lésions
# Processing: P45 T1 T1: 15 lésions
# Processing: P45 T1 T2: 15 lésions
# Processing: P45 T1 FLAIR: 15 lésions
# Processing: P46 T1 T1: 27 lésions
# Processing: P46 T1 T2: 27 lésions
# Processing: P46 T1 FLAIR: 27 lésions
# Processing: P47 T1 T1: 59 lésions
# Processing: P47 T1 T2: 59 lésions
# Processing: P47 T1 FLAIR: 59 lésions
# Processing: P48 T1 T1: 43 lésions
# Processing: P48 T1 T2: 43 lésions
# Processing: P48 T1 FLAIR: 43 lésions
# Processing: P49 T1 T1: 30 lésions
# Processing: P49 T1 T2: 30 lésions
# Processing: P49 T1 FLAIR: 30 lésions
# Processing: P49 T2 T1: 19 lésions
# Processing: P49 T2 T2: 19 lésions
# Processing: P49 T2 FLAIR: 19 lésions
# Processing: P5 T1 T1: 24 lésions
# Processing: P5 T1 T2: 24 lésions
# Processing: P5 T1 FLAIR: 24 lésions
# Processing: P5 T2 T1: 13 lésions
# Processing: P5 T2 T2: 13 lésions
# Processing: P5 T2 FLAIR: 13 lésions
# Processing: P50 T1 T1: 47 lésions
# Processing: P50 T1 T2: 47 lésions
# Processing: P50 T1 FLAIR: 47 lésions
# Processing: P50 T2 T1: 41 lésions
# Processing: P50 T2 T2: 41 lésions
# Processing: P50 T2 FLAIR: 41 lésions
# Processing: P51 T1 T1: 44 lésions
# Processing: P51 T1 T2: 44 lésions
# Processing: P51 T1 FLAIR: 44 lésions
# Processing: P51 T2 T1: 39 lésions
# Processing: P51 T2 T2: 39 lésions
# Processing: P51 T2 FLAIR: 39 lésions
# Processing: P52 T1 T1: 28 lésions
# Processing: P52 T1 T2: 28 lésions
# Processing: P52 T1 FLAIR: 28 lésions
# Processing: P52 T2 T1: 14 lésions
# Processing: P52 T2 T2: 14 lésions
# Processing: P52 T2 FLAIR: 14 lésions
# Processing: P53 T1 T1: 22 lésions
# Processing: P53 T1 T2: 22 lésions
# Processing: P53 T1 FLAIR: 22 lésions
# Processing: P53 T2 T1: 24 lésions
# Processing: P53 T2 T2: 24 lésions
# Processing: P53 T2 FLAIR: 24 lésions
# Processing: P6 T1 T1: 37 lésions
# Processing: P6 T1 T2: 37 lésions
# Processing: P6 T1 FLAIR: 37 lésions
# Processing: P6 T2 T1: 33 lésions
# Processing: P6 T2 T2: 33 lésions
# Processing: P6 T2 FLAIR: 33 lésions
# Processing: P6 T3 T1: 41 lésions
# Processing: P6 T3 T2: 41 lésions
# Processing: P6 T3 FLAIR: 41 lésions
# Processing: P7 T1 T1: 24 lésions
# Processing: P7 T1 T2: 24 lésions
# Processing: P7 T1 FLAIR: 24 lésions
# Processing: P7 T2 T1: 23 lésions
# Processing: P7 T2 T2: 23 lésions
# Processing: P7 T2 FLAIR: 23 lésions
# Processing: P8 T1 T1: 18 lésions
# Processing: P8 T1 T2: 18 lésions
# Processing: P8 T1 FLAIR: 18 lésions
# Processing: P8 T2 T1: 21 lésions
# Processing: P8 T2 T2: 21 lésions
# Processing: P8 T2 FLAIR: 21 lésions
# Processing: P9 T1 T1: 16 lésions
# Processing: P9 T1 T2: 16 lésions
# Processing: P9 T1 FLAIR: 16 lésions
# Processing: P9 T2 T1: 22 lésions
# Processing: P9 T2 T2: 22 lésions
# Processing: P9 T2 FLAIR: 22 lésions
# Processing: P9 T3 T1: 15 lésions
# Processing: P9 T3 T2: 15 lésions
# Processing: P9 T3 FLAIR: 15 lésions
#
# [SUCCÈS] Toutes les lésions de tous les patients ont été extraites.
