# %%
import os
import csv
import numpy as np
import SimpleITK as sitk

# %%
# =================================================================
# 1. CONFIGURATION DES CHEMINS
# =================================================================
ROOT_TRAIN = "../../../27919209/MSLesSegDataset/train"
GLOBAL_OUTPUT_DIR = "Moments_Extraction_3D_Results"
MODALITIES = ["T1", "T2", "FLAIR"]
ORDRE_CIBLE = 10 # 10x10x10 = 1000 coefficients

# %%
# =================================================================
# 2. MOTEUR MATHÉMATIQUE 3D STABLE
# =================================================================

def tchebichef_polynomials(N, order):
    """Calcule les polynômes via la récurrence de Mukundan."""
    M = np.zeros((order, N))
    x = np.arange(N)
    M[0, :] = 1.0
    if order > 1:
        M[1, :] = (2.0 * x - N + 1.0) / N
    for p in range(2, order):
        term1 = ((2.0 * p - 1.0) * (2.0 * x - N + 1.0)) / (p * N)
        term2 = ((p - 1.0) / p) * (1.0 - ((p - 1.0)**2 / (N**2)))
        M[p, :] = term1 * M[p-1, :] - term2 * M[p-2, :]
    return M

def calculate_rho(N, order):
    """Constante de normalisation pour l'orthogonalité."""
    rho = np.zeros(order)
    rho[0] = N
    for p in range(1, order):
        term1 = (N**2 - p**2) / (N**2)
        term2 = (2*p - 1) / (2*p + 1)
        rho[p] = term1 * term2 * rho[p-1]
    return rho

def decompose_3d(volume, requested_order):
    """Génère le tenseur des moments T_pqr (10x10x10)."""
    D, H, W = volume.shape
    
    # Sécurité pour les dimensions plus petites que l'ordre
    o_d, o_h, o_w = min(requested_order, D), min(requested_order, H), min(requested_order, W)
    
    # Génération des matrices de polynômes
    M_d = tchebichef_polynomials(D, o_d)
    M_h = tchebichef_polynomials(H, o_h)
    M_w = tchebichef_polynomials(W, o_w)
    
    # Normalisation rho
    rho_d = calculate_rho(D, o_d)
    rho_h = calculate_rho(H, o_h)
    rho_w = calculate_rho(W, o_w)
    
    # Calcul des moments par produit tensoriel (np.einsum est le plus efficace ici)
    # T_pqr = sum_z sum_y sum_x f(z,y,x) * Mz(p,z) * My(q,y) * Mx(r,x)
    T_raw = np.einsum('zyx,pz,qy,rx->pqr', volume, M_d, M_h, M_w)
    
    # Application de la normalisation 3D
    norm_factor = 1.0 / (np.einsum('p,q,r->pqr', rho_d, rho_h, rho_w))
    T_pqr_small = T_raw * norm_factor
    
    # Remplissage du tenseur 10x10x10 final
    T_final = np.zeros((requested_order, requested_order, requested_order))
    T_final[:o_d, :o_h, :o_w] = T_pqr_small
    
    # Arrondi à 3 décimales
    return np.round(T_final, 3)

# %%
# =================================================================
# 3. BOUCLE MASTER (TOUS PATIENTS, TIMEPOINTS, MODALITÉS)
# =================================================================

os.makedirs(GLOBAL_OUTPUT_DIR, exist_ok=True)
patients = sorted([d for d in os.listdir(ROOT_TRAIN) if os.path.isdir(os.path.join(ROOT_TRAIN, d))])

for patient in patients:
    patient_path = os.path.join(ROOT_TRAIN, patient)
    timepoints = sorted([d for d in os.listdir(patient_path) if os.path.isdir(os.path.join(patient_path, d))])
    
    for tp in timepoints:
        tp_path = os.path.join(patient_path, tp)
        out_dir = os.path.join(GLOBAL_OUTPUT_DIR, patient, tp)
        os.makedirs(out_dir, exist_ok=True)
        
        # 1. Gestion du Masque 3D
        mask_path = os.path.join(tp_path, f"{patient}_{tp}_MASK.nii.gz")
        if not os.path.exists(mask_path): continue
        
        mask_sitk = sitk.ReadImage(mask_path)
        mask_bin = sitk.Cast(mask_sitk > 0, sitk.sitkUInt8)
        # Isolation et tri des lésions par volume
        lesion_cc = sitk.RelabelComponent(sitk.ConnectedComponent(mask_bin))
        mask_arr = sitk.GetArrayFromImage(lesion_cc)
        num_lesions = int(mask_arr.max())
        
        # 2. Boucle sur les modalités
        for modality in MODALITIES:
            img_path = os.path.join(tp_path, f"{patient}_{tp}_{modality}.nii.gz")
            if not os.path.exists(img_path): continue
            
            img_arr = sitk.GetArrayFromImage(sitk.ReadImage(img_path))
            print(f"Traitement 3D : {patient} | {tp} | {modality} ({num_lesions} lésions)")
            
            for l_id in range(1, num_lesions + 1):
                # Extraction du volume de la lésion (ROI 3D)
                indices = np.where(mask_arr == l_id)
                if indices[0].size < 8: continue # Filtre mini (2x2x2 voxels)
                
                # Bounding Box 3D
                z_min, z_max = indices[0].min(), indices[0].max()
                y_min, y_max = indices[1].min(), indices[1].max()
                x_min, x_max = indices[2].min(), indices[2].max()
                
                roi_vol = img_arr[z_min:z_max+1, y_min:y_max+1, x_min:x_max+1]
                roi_mask = (mask_arr[z_min:z_max+1, y_min:y_max+1, x_min:x_max+1] == l_id)
                
                # Signal pur (Intensité * Masque)
                roi_signal = roi_vol * roi_mask
                
                # Normalisation intensité (0-1)
                v_max = np.max(roi_signal)
                roi_norm = roi_signal / v_max if v_max > 0 else roi_signal
                
                # Décomposition 3D
                moments_3d = decompose_3d(roi_norm, ORDRE_CIBLE)
                
                # Sauvegarde : On aplatit les 1000 coefficients en un seul vecteur pour le CSV
                flat_moments = moments_3d.flatten()
                csv_name = f"{patient}_{tp}_{modality}_L{l_id}_Cheby3D.csv"
                
                with open(os.path.join(out_dir, csv_name), "w", newline="") as f:
                    writer = csv.writer(f)
                    # On écrit les 1000 coefficients sur une seule ligne (ou colonne)
                    writer.writerow(flat_moments)

print("\n[TERMINÉ] Extraction 3D de tous les patients effectuée.")
# Out:
# Traitement 3D : P1 | T1 | T1 (18 lésions)
# Traitement 3D : P1 | T1 | T2 (18 lésions)
# Traitement 3D : P1 | T1 | FLAIR (18 lésions)
# Traitement 3D : P1 | T2 | T1 (18 lésions)
# Traitement 3D : P1 | T2 | T2 (18 lésions)
# Traitement 3D : P1 | T2 | FLAIR (18 lésions)
# Traitement 3D : P1 | T3 | T1 (14 lésions)
# Traitement 3D : P1 | T3 | T2 (14 lésions)
# Traitement 3D : P1 | T3 | FLAIR (14 lésions)
# Traitement 3D : P10 | T1 | T1 (35 lésions)
# Traitement 3D : P10 | T1 | T2 (35 lésions)
# Traitement 3D : P10 | T1 | FLAIR (35 lésions)
# Traitement 3D : P10 | T2 | T1 (32 lésions)
# Traitement 3D : P10 | T2 | T2 (32 lésions)
# Traitement 3D : P10 | T2 | FLAIR (32 lésions)
# Traitement 3D : P11 | T1 | T1 (15 lésions)
# Traitement 3D : P11 | T1 | T2 (15 lésions)
# Traitement 3D : P11 | T1 | FLAIR (15 lésions)
# Traitement 3D : P11 | T2 | T1 (10 lésions)
# Traitement 3D : P11 | T2 | T2 (10 lésions)
# Traitement 3D : P11 | T2 | FLAIR (10 lésions)
# Traitement 3D : P12 | T1 | T1 (36 lésions)
# Traitement 3D : P12 | T1 | T2 (36 lésions)
# Traitement 3D : P12 | T1 | FLAIR (36 lésions)
# Traitement 3D : P12 | T2 | T1 (42 lésions)
# Traitement 3D : P12 | T2 | T2 (42 lésions)
# Traitement 3D : P12 | T2 | FLAIR (42 lésions)
# Traitement 3D : P12 | T3 | T1 (44 lésions)
# Traitement 3D : P12 | T3 | T2 (44 lésions)
# Traitement 3D : P12 | T3 | FLAIR (44 lésions)
# Traitement 3D : P12 | T4 | T1 (43 lésions)
# Traitement 3D : P12 | T4 | T2 (43 lésions)
# Traitement 3D : P12 | T4 | FLAIR (43 lésions)
# Traitement 3D : P13 | T1 | T1 (39 lésions)
# Traitement 3D : P13 | T1 | T2 (39 lésions)
# Traitement 3D : P13 | T1 | FLAIR (39 lésions)
# Traitement 3D : P13 | T2 | T1 (61 lésions)
# Traitement 3D : P13 | T2 | T2 (61 lésions)
# Traitement 3D : P13 | T2 | FLAIR (61 lésions)
# Traitement 3D : P14 | T1 | T1 (17 lésions)
# Traitement 3D : P14 | T1 | T2 (17 lésions)
# Traitement 3D : P14 | T1 | FLAIR (17 lésions)
# Traitement 3D : P14 | T2 | T1 (17 lésions)
# Traitement 3D : P14 | T2 | T2 (17 lésions)
# Traitement 3D : P14 | T2 | FLAIR (17 lésions)
# Traitement 3D : P14 | T3 | T1 (29 lésions)
# Traitement 3D : P14 | T3 | T2 (29 lésions)
# Traitement 3D : P14 | T3 | FLAIR (29 lésions)
# Traitement 3D : P14 | T4 | T1 (28 lésions)
# Traitement 3D : P14 | T4 | T2 (28 lésions)
# Traitement 3D : P14 | T4 | FLAIR (28 lésions)
# Traitement 3D : P15 | T1 | T1 (6 lésions)
# Traitement 3D : P15 | T1 | T2 (6 lésions)
# Traitement 3D : P15 | T1 | FLAIR (6 lésions)
# Traitement 3D : P16 | T1 | T1 (4 lésions)
# Traitement 3D : P16 | T1 | T2 (4 lésions)
# Traitement 3D : P16 | T1 | FLAIR (4 lésions)
# Traitement 3D : P17 | T1 | T1 (11 lésions)
# Traitement 3D : P17 | T1 | T2 (11 lésions)
# Traitement 3D : P17 | T1 | FLAIR (11 lésions)
# Traitement 3D : P18 | T1 | T1 (3 lésions)
# Traitement 3D : P18 | T1 | T2 (3 lésions)
# Traitement 3D : P18 | T1 | FLAIR (3 lésions)
# Traitement 3D : P19 | T1 | T1 (61 lésions)
# Traitement 3D : P19 | T1 | T2 (61 lésions)
# Traitement 3D : P19 | T1 | FLAIR (61 lésions)
# Traitement 3D : P19 | T2 | T1 (56 lésions)
# Traitement 3D : P19 | T2 | T2 (56 lésions)
# Traitement 3D : P19 | T2 | FLAIR (56 lésions)
# Traitement 3D : P19 | T3 | T1 (64 lésions)
# Traitement 3D : P19 | T3 | T2 (64 lésions)
# Traitement 3D : P19 | T3 | FLAIR (64 lésions)
# Traitement 3D : P19 | T4 | T1 (26 lésions)
# Traitement 3D : P19 | T4 | T2 (26 lésions)
# Traitement 3D : P19 | T4 | FLAIR (26 lésions)
# Traitement 3D : P2 | T1 | T1 (16 lésions)
# Traitement 3D : P2 | T1 | T2 (16 lésions)
# Traitement 3D : P2 | T1 | FLAIR (16 lésions)
# Traitement 3D : P2 | T2 | T1 (20 lésions)
# Traitement 3D : P2 | T2 | T2 (20 lésions)
# Traitement 3D : P2 | T2 | FLAIR (20 lésions)
# Traitement 3D : P2 | T3 | T1 (14 lésions)
# Traitement 3D : P2 | T3 | T2 (14 lésions)
# Traitement 3D : P2 | T3 | FLAIR (14 lésions)
# Traitement 3D : P2 | T4 | T1 (18 lésions)
# Traitement 3D : P2 | T4 | T2 (18 lésions)
# Traitement 3D : P2 | T4 | FLAIR (18 lésions)
# Traitement 3D : P20 | T1 | T1 (8 lésions)
# Traitement 3D : P20 | T1 | T2 (8 lésions)
# Traitement 3D : P20 | T1 | FLAIR (8 lésions)
# Traitement 3D : P20 | T2 | T1 (26 lésions)
# Traitement 3D : P20 | T2 | T2 (26 lésions)
# Traitement 3D : P20 | T2 | FLAIR (26 lésions)
# Traitement 3D : P20 | T3 | T1 (13 lésions)
# Traitement 3D : P20 | T3 | T2 (13 lésions)
# Traitement 3D : P20 | T3 | FLAIR (13 lésions)
# Traitement 3D : P21 | T1 | T1 (13 lésions)
# Traitement 3D : P21 | T1 | T2 (13 lésions)
# Traitement 3D : P21 | T1 | FLAIR (13 lésions)
# Traitement 3D : P22 | T1 | T1 (21 lésions)
# Traitement 3D : P22 | T1 | T2 (21 lésions)
# Traitement 3D : P22 | T1 | FLAIR (21 lésions)
# Traitement 3D : P22 | T2 | T1 (21 lésions)
# Traitement 3D : P22 | T2 | T2 (21 lésions)
# Traitement 3D : P22 | T2 | FLAIR (21 lésions)
# Traitement 3D : P23 | T1 | T1 (20 lésions)
# Traitement 3D : P23 | T1 | T2 (20 lésions)
# Traitement 3D : P23 | T1 | FLAIR (20 lésions)
# Traitement 3D : P24 | T1 | T1 (57 lésions)
# Traitement 3D : P24 | T1 | T2 (57 lésions)
# Traitement 3D : P24 | T1 | FLAIR (57 lésions)
# Traitement 3D : P25 | T1 | T1 (6 lésions)
# Traitement 3D : P25 | T1 | T2 (6 lésions)
# Traitement 3D : P25 | T1 | FLAIR (6 lésions)
# Traitement 3D : P26 | T1 | T1 (43 lésions)
# Traitement 3D : P26 | T1 | T2 (43 lésions)
# Traitement 3D : P26 | T1 | FLAIR (43 lésions)
# Traitement 3D : P27 | T1 | T1 (25 lésions)
# Traitement 3D : P27 | T1 | T2 (25 lésions)
# Traitement 3D : P27 | T1 | FLAIR (25 lésions)
# Traitement 3D : P28 | T1 | T1 (8 lésions)
# Traitement 3D : P28 | T1 | T2 (8 lésions)
# Traitement 3D : P28 | T1 | FLAIR (8 lésions)
# Traitement 3D : P28 | T2 | T1 (21 lésions)
# Traitement 3D : P28 | T2 | T2 (21 lésions)
# Traitement 3D : P28 | T2 | FLAIR (21 lésions)
# Traitement 3D : P29 | T1 | T1 (27 lésions)
# Traitement 3D : P29 | T1 | T2 (27 lésions)
# Traitement 3D : P29 | T1 | FLAIR (27 lésions)
# Traitement 3D : P3 | T1 | T1 (42 lésions)
# Traitement 3D : P3 | T1 | T2 (42 lésions)
# Traitement 3D : P3 | T1 | FLAIR (42 lésions)
# Traitement 3D : P3 | T2 | T1 (16 lésions)
# Traitement 3D : P3 | T2 | T2 (16 lésions)
# Traitement 3D : P3 | T2 | FLAIR (16 lésions)
# Traitement 3D : P3 | T3 | T1 (26 lésions)
# Traitement 3D : P3 | T3 | T2 (26 lésions)
# Traitement 3D : P3 | T3 | FLAIR (26 lésions)
# Traitement 3D : P3 | T4 | T1 (25 lésions)
# Traitement 3D : P3 | T4 | T2 (25 lésions)
# Traitement 3D : P3 | T4 | FLAIR (25 lésions)
# Traitement 3D : P30 | T1 | T1 (6 lésions)
# Traitement 3D : P30 | T1 | T2 (6 lésions)
# Traitement 3D : P30 | T1 | FLAIR (6 lésions)
# Traitement 3D : P31 | T1 | T1 (29 lésions)
# Traitement 3D : P31 | T1 | T2 (29 lésions)
# Traitement 3D : P31 | T1 | FLAIR (29 lésions)
# Traitement 3D : P31 | T2 | T1 (31 lésions)
# Traitement 3D : P31 | T2 | T2 (31 lésions)
# Traitement 3D : P31 | T2 | FLAIR (31 lésions)
# Traitement 3D : P32 | T1 | T1 (12 lésions)
# Traitement 3D : P32 | T1 | T2 (12 lésions)
# Traitement 3D : P32 | T1 | FLAIR (12 lésions)
# Traitement 3D : P33 | T1 | T1 (44 lésions)
# Traitement 3D : P33 | T1 | T2 (44 lésions)
# Traitement 3D : P33 | T1 | FLAIR (44 lésions)
# Traitement 3D : P33 | T2 | T1 (31 lésions)
# Traitement 3D : P33 | T2 | T2 (31 lésions)
# Traitement 3D : P33 | T2 | FLAIR (31 lésions)
# Traitement 3D : P34 | T1 | T1 (32 lésions)
# Traitement 3D : P34 | T1 | T2 (32 lésions)
# Traitement 3D : P34 | T1 | FLAIR (32 lésions)
# Traitement 3D : P35 | T1 | T1 (109 lésions)
# Traitement 3D : P35 | T1 | T2 (109 lésions)
# Traitement 3D : P35 | T1 | FLAIR (109 lésions)
# Traitement 3D : P36 | T1 | T1 (79 lésions)
# Traitement 3D : P36 | T1 | T2 (79 lésions)
# Traitement 3D : P36 | T1 | FLAIR (79 lésions)
# Traitement 3D : P37 | T1 | T1 (16 lésions)
# Traitement 3D : P37 | T1 | T2 (16 lésions)
# Traitement 3D : P37 | T1 | FLAIR (16 lésions)
# Traitement 3D : P38 | T1 | T1 (111 lésions)
# Traitement 3D : P38 | T1 | T2 (111 lésions)
# Traitement 3D : P38 | T1 | FLAIR (111 lésions)
# Traitement 3D : P39 | T1 | T1 (35 lésions)
# Traitement 3D : P39 | T1 | T2 (35 lésions)
# Traitement 3D : P39 | T1 | FLAIR (35 lésions)
# Traitement 3D : P4 | T1 | T1 (22 lésions)
# Traitement 3D : P4 | T1 | T2 (22 lésions)
# Traitement 3D : P4 | T1 | FLAIR (22 lésions)
# Traitement 3D : P4 | T2 | T1 (28 lésions)
# Traitement 3D : P4 | T2 | T2 (28 lésions)
# Traitement 3D : P4 | T2 | FLAIR (28 lésions)
# Traitement 3D : P4 | T3 | T1 (21 lésions)
# Traitement 3D : P4 | T3 | T2 (21 lésions)
# Traitement 3D : P4 | T3 | FLAIR (21 lésions)
# Traitement 3D : P40 | T1 | T1 (23 lésions)
# Traitement 3D : P40 | T1 | T2 (23 lésions)
# Traitement 3D : P40 | T1 | FLAIR (23 lésions)
# Traitement 3D : P41 | T1 | T1 (10 lésions)
# Traitement 3D : P41 | T1 | T2 (10 lésions)
# Traitement 3D : P41 | T1 | FLAIR (10 lésions)
# Traitement 3D : P42 | T1 | T1 (44 lésions)
# Traitement 3D : P42 | T1 | T2 (44 lésions)
# Traitement 3D : P42 | T1 | FLAIR (44 lésions)
# Traitement 3D : P43 | T1 | T1 (40 lésions)
# Traitement 3D : P43 | T1 | T2 (40 lésions)
# Traitement 3D : P43 | T1 | FLAIR (40 lésions)
# Traitement 3D : P44 | T1 | T1 (11 lésions)
# Traitement 3D : P44 | T1 | T2 (11 lésions)
# Traitement 3D : P44 | T1 | FLAIR (11 lésions)
# Traitement 3D : P45 | T1 | T1 (15 lésions)
# Traitement 3D : P45 | T1 | T2 (15 lésions)
# Traitement 3D : P45 | T1 | FLAIR (15 lésions)
# Traitement 3D : P46 | T1 | T1 (27 lésions)
# Traitement 3D : P46 | T1 | T2 (27 lésions)
# Traitement 3D : P46 | T1 | FLAIR (27 lésions)
# Traitement 3D : P47 | T1 | T1 (59 lésions)
# Traitement 3D : P47 | T1 | T2 (59 lésions)
# Traitement 3D : P47 | T1 | FLAIR (59 lésions)
# Traitement 3D : P48 | T1 | T1 (43 lésions)
# Traitement 3D : P48 | T1 | T2 (43 lésions)
# Traitement 3D : P48 | T1 | FLAIR (43 lésions)
# Traitement 3D : P49 | T1 | T1 (30 lésions)
# Traitement 3D : P49 | T1 | T2 (30 lésions)
# Traitement 3D : P49 | T1 | FLAIR (30 lésions)
# Traitement 3D : P49 | T2 | T1 (19 lésions)
# Traitement 3D : P49 | T2 | T2 (19 lésions)
# Traitement 3D : P49 | T2 | FLAIR (19 lésions)
# Traitement 3D : P5 | T1 | T1 (24 lésions)
# Traitement 3D : P5 | T1 | T2 (24 lésions)
# Traitement 3D : P5 | T1 | FLAIR (24 lésions)
# Traitement 3D : P5 | T2 | T1 (13 lésions)
# Traitement 3D : P5 | T2 | T2 (13 lésions)
# Traitement 3D : P5 | T2 | FLAIR (13 lésions)
# Traitement 3D : P50 | T1 | T1 (47 lésions)
# Traitement 3D : P50 | T1 | T2 (47 lésions)
# Traitement 3D : P50 | T1 | FLAIR (47 lésions)
# Traitement 3D : P50 | T2 | T1 (41 lésions)
# Traitement 3D : P50 | T2 | T2 (41 lésions)
# Traitement 3D : P50 | T2 | FLAIR (41 lésions)
# Traitement 3D : P51 | T1 | T1 (44 lésions)
# Traitement 3D : P51 | T1 | T2 (44 lésions)
# Traitement 3D : P51 | T1 | FLAIR (44 lésions)
# Traitement 3D : P51 | T2 | T1 (39 lésions)
# Traitement 3D : P51 | T2 | T2 (39 lésions)
# Traitement 3D : P51 | T2 | FLAIR (39 lésions)
# Traitement 3D : P52 | T1 | T1 (28 lésions)
# Traitement 3D : P52 | T1 | T2 (28 lésions)
# Traitement 3D : P52 | T1 | FLAIR (28 lésions)
# Traitement 3D : P52 | T2 | T1 (14 lésions)
# Traitement 3D : P52 | T2 | T2 (14 lésions)
# Traitement 3D : P52 | T2 | FLAIR (14 lésions)
# Traitement 3D : P53 | T1 | T1 (22 lésions)
# Traitement 3D : P53 | T1 | T2 (22 lésions)
# Traitement 3D : P53 | T1 | FLAIR (22 lésions)
# Traitement 3D : P53 | T2 | T1 (24 lésions)
# Traitement 3D : P53 | T2 | T2 (24 lésions)
# Traitement 3D : P53 | T2 | FLAIR (24 lésions)
# Traitement 3D : P6 | T1 | T1 (37 lésions)
# Traitement 3D : P6 | T1 | T2 (37 lésions)
# Traitement 3D : P6 | T1 | FLAIR (37 lésions)
# Traitement 3D : P6 | T2 | T1 (33 lésions)
# Traitement 3D : P6 | T2 | T2 (33 lésions)
# Traitement 3D : P6 | T2 | FLAIR (33 lésions)
# Traitement 3D : P6 | T3 | T1 (41 lésions)
# Traitement 3D : P6 | T3 | T2 (41 lésions)
# Traitement 3D : P6 | T3 | FLAIR (41 lésions)
# Traitement 3D : P7 | T1 | T1 (24 lésions)
# Traitement 3D : P7 | T1 | T2 (24 lésions)
# Traitement 3D : P7 | T1 | FLAIR (24 lésions)
# Traitement 3D : P7 | T2 | T1 (23 lésions)
# Traitement 3D : P7 | T2 | T2 (23 lésions)
# Traitement 3D : P7 | T2 | FLAIR (23 lésions)
# Traitement 3D : P8 | T1 | T1 (18 lésions)
# Traitement 3D : P8 | T1 | T2 (18 lésions)
# Traitement 3D : P8 | T1 | FLAIR (18 lésions)
# Traitement 3D : P8 | T2 | T1 (21 lésions)
# Traitement 3D : P8 | T2 | T2 (21 lésions)
# Traitement 3D : P8 | T2 | FLAIR (21 lésions)
# Traitement 3D : P9 | T1 | T1 (16 lésions)
# Traitement 3D : P9 | T1 | T2 (16 lésions)
# Traitement 3D : P9 | T1 | FLAIR (16 lésions)
# Traitement 3D : P9 | T2 | T1 (22 lésions)
# Traitement 3D : P9 | T2 | T2 (22 lésions)
# Traitement 3D : P9 | T2 | FLAIR (22 lésions)
# Traitement 3D : P9 | T3 | T1 (15 lésions)
# Traitement 3D : P9 | T3 | T2 (15 lésions)
# Traitement 3D : P9 | T3 | FLAIR (15 lésions)
#
# [TERMINÉ] Extraction 3D de tous les patients effectuée.
